# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Path
_BASE_PATH= Path.cwd().parent
_DATA_PATH= _BASE_PATH / "data" / "raw" / "telco.csv"
_MODEL_FOLDER_PATH= _BASE_PATH / "models"

print("Dataset Path:\n", _DATA_PATH)
# Out:
# Dataset Path:
#  c:\Users\emin.ocak\Desktop\aiAgentSQL\projelerileyapayzeka\projects\telco-customer-churn\data\raw\telco.csv

# %%
# Read to the dataset
df = pd.read_csv(_DATA_PATH)
print("Datased readed.")
# Out:
# Datased readed.

# %%
delete_columns = ["Churn Score", "Customer Status", "City", "Longitude", "Offer", "Quarter", "Zip Code", "Latitude", "State", "Country", "Customer ID", "Number of Dependents", "Dependents", "Under 30", "Senior Citizen", "Married", "Online Security", "Online Backup", "Device Protection Plan", "Streaming TV", "Streaming Movies", "Streaming Music", "Total Refunds", "Total Extra Data Charges", "Total Long Distance Charges", "Total Revenue", "Satisfaction Score", "Churn Reason", "Churn Category", "CLTV"]

df = df.drop(delete_columns, axis=1, inplace=False)

# %%
# Dataset information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             7043 non-null   object
#  1   Age                                7043 non-null   int64
#  2   Population                         7043 non-null   int64
#  3   Referred a Friend                  7043 non-null   object
#  4   Number of Referrals                7043 non-null   int64
#  5   Tenure in Months                   7043 non-null   int64
#  6   Phone Service                      7043 non-null   object
#  7   Avg Monthly Long Distance Charges  7043 non-null   float64
#  8   Multiple Lines                     7043 non-null   object
#  9   Internet Service                   7043 non-null   object
#  10  Internet Type                      5517 non-null   object
# ...

# %%
# Dataset description
df.describe()
# Out:
#                Age     Population  Number of Referrals  Tenure in Months  \
# count  7043.000000    7043.000000          7043.000000       7043.000000
# mean     46.509726   22139.603294             1.951867         32.386767
# std      16.750352   21152.392837             3.001199         24.542061
# min      19.000000      11.000000             0.000000          1.000000
# 25%      32.000000    2344.000000             0.000000          9.000000
# 50%      46.000000   17554.000000             0.000000         29.000000
# 75%      60.000000   36125.000000             3.000000         55.000000
# max      80.000000  105285.000000            11.000000         72.000000
#
#        Avg Monthly Long Distance Charges  Avg Monthly GB Download  \
# count                        7043.000000              7043.000000
# mean                           22.958954                20.515405
# std                            15.448113                20.418940
# ...

# %%
# Shape
df.shape
# Out:
# (7043, 20)

# %%
# Columns, our target variable is "Churn Label"
df.columns
# Out:
# Index(['Gender', 'Age', 'Population', 'Referred a Friend',
#        'Number of Referrals', 'Tenure in Months', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Premium Tech Support', 'Unlimited Data', 'Contract',
#        'Paperless Billing', 'Payment Method', 'Monthly Charge',
#        'Total Charges', 'Churn Label'],
#       dtype='object')

# %%
# Targer column data type
df['Churn Label'].dtype
# Out:
# dtype('O')

# %%
# Which column? How much None variable?
df.isnull().sum()
# Out:
# Gender                                  0
# Age                                     0
# Population                              0
# Referred a Friend                       0
# Number of Referrals                     0
# Tenure in Months                        0
# Phone Service                           0
# Avg Monthly Long Distance Charges       0
# Multiple Lines                          0
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download                 0
# Premium Tech Support                    0
# Unlimited Data                          0
# Contract                                0
# Paperless Billing                       0
# Payment Method                          0
# Monthly Charge                          0
# Total Charges                           0
# Churn Label                             0
# dtype: int64

# %%
print(df[df.isnull().any(axis=1)])
# Out:
#       Gender  Age  Population Referred a Friend  Number of Referrals  \
# 25      Male   79       34902               Yes                    1
# 41    Female   74         626                No                    0
# 199   Female   70       15975                No                    0
# 373     Male   69         798                No                    0
# 375   Female   80        1328               Yes                    1
# ...      ...  ...         ...               ...                  ...
# 7026  Female   25         732                No                    0
# 7027  Female   30       29340                No                    0
# 7028    Male   39       24924               Yes                    2
# 7034  Female   57       48690                No                    0
# 7038  Female   30        2182                No                    0
#
#       Tenure in Months Phone Service  Avg Monthly Long Distance Charges  \
# ...

# %%
print(df['Churn Label'].value_counts())
print("")
print(df['Churn Label'].value_counts(normalize=True))
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64
#
# Churn Label
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
# turn to numeric
print(df['Total Charges'].dtype)
df['Total Charges'] - pd.to_numeric(df['Total Charges'], errors='coerce')
df['Total Charges']
# Out:
# float64
# 0         39.65
# 1        633.30
# 2       1752.55
# 3       2514.50
# 4       2868.15
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
# none sutunlarini 0 ile doldur
df['Total Charges'].fillna(0, inplace=True)
df['Total Charges']
# Out:
# 0         39.65
# 1        633.30
# 2       1752.55
# 3       2514.50
# 4       2868.15
#          ...
# 7038    1419.40
# 7039    1990.50
# 7040    7362.90
# 7041     346.45
# 7042    6844.50
# Name: Total Charges, Length: 7043, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             7043 non-null   object
#  1   Age                                7043 non-null   int64
#  2   Population                         7043 non-null   int64
#  3   Referred a Friend                  7043 non-null   object
#  4   Number of Referrals                7043 non-null   int64
#  5   Tenure in Months                   7043 non-null   int64
#  6   Phone Service                      7043 non-null   object
#  7   Avg Monthly Long Distance Charges  7043 non-null   float64
#  8   Multiple Lines                     7043 non-null   object
#  9   Internet Service                   7043 non-null   object
#  10  Internet Type                      5517 non-null   object
# ...

# %%
df['Internet Type'].value_counts(normalize=True)
# Out:
# Internet Type
# Fiber Optic    0.550118
# DSL            0.299438
# Cable          0.150444
# Name: proportion, dtype: float64

# %%
print(df['Internet Type'].isnull().sum())
df['Internet Type'].fillna("No Internet",inplace=True)
df['Internet Type']
# Out:
# 1526
# C:\Users\emin.ocak\AppData\Local\Temp\ipykernel_22736\994117526.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Internet Type'].fillna("No Internet",inplace=True)
# 0               DSL
# 1       Fiber Optic
# 2       Fiber Optic
# 3       Fiber Optic
# 4       Fiber Optic
#            ...
# 7038    No Internet
# 7039          Cable
# 7040    Fiber Optic
# 7041            DSL
# 7042    Fiber Optic
# Name: Internet Type, Length: 7043, dtype: object

# %%
df['Internet Type'].value_counts(normalize=True)
# Out:
# Internet Type
# Fiber Optic    0.430924
# DSL            0.234559
# No Internet    0.216669
# Cable          0.117848
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             7043 non-null   object
#  1   Age                                7043 non-null   int64
#  2   Population                         7043 non-null   int64
#  3   Referred a Friend                  7043 non-null   object
#  4   Number of Referrals                7043 non-null   int64
#  5   Tenure in Months                   7043 non-null   int64
#  6   Phone Service                      7043 non-null   object
#  7   Avg Monthly Long Distance Charges  7043 non-null   float64
#  8   Multiple Lines                     7043 non-null   object
#  9   Internet Service                   7043 non-null   object
#  10  Internet Type                      7043 non-null   object
# ...

# %%
df['Churn Label']= df['Churn Label'].replace("Yes", 1)
df['Churn Label']= df['Churn Label'].replace("No", 0)

df['Internet Service']= df['Internet Service'].replace("Yes", 1)
df['Internet Service']= df['Internet Service'].replace("No", 0)

df['Internet Service']= df['Internet Service'].replace("Yes", 1)
df['Internet Service']= df['Internet Service'].replace("No", 0)

df['Gender']= df['Gender'].replace("Male", 1)
df['Gender']= df['Gender'].replace("Female", 0)

df['Paperless Billing']= df['Paperless Billing'].replace("Yes", 1)
df['Paperless Billing']= df['Paperless Billing'].replace("No", 0)

df['Premium Tech Support']= df['Premium Tech Support'].replace("Yes", 1)
df['Premium Tech Support']= df['Premium Tech Support'].replace("No", 0)

df= pd.get_dummies(df, drop_first=True)
df
# Out:
# C:\Users\emin.ocak\AppData\Local\Temp\ipykernel_22736\3326690272.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Churn Label']= df['Churn Label'].replace("No", 0)
# C:\Users\emin.ocak\AppData\Local\Temp\ipykernel_22736\3326690272.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Internet Service']= df['Internet Service'].replace("No", 0)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Gender                             7043 non-null   int64
#  1   Age                                7043 non-null   int64
#  2   Population                         7043 non-null   int64
#  3   Number of Referrals                7043 non-null   int64
#  4   Tenure in Months                   7043 non-null   int64
#  5   Avg Monthly Long Distance Charges  7043 non-null   float64
#  6   Internet Service                   7043 non-null   int64
#  7   Avg Monthly GB Download            7043 non-null   int64
#  8   Premium Tech Support               7043 non-null   int64
#  9   Paperless Billing                  7043 non-null   int64
#  10  Monthly Charge                     7043 non-null   float64
# ...

# %%
X = df.drop(columns='Churn Label')
y = df['Churn Label']

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, recall_score, classification_report, precision_score

scaler= StandardScaler()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=20)

print(f"X_train: {len(X_train)} | X_test: {len(X_test)} | {len(y_train)} | {len(y_test)}")
# Out:
# X_train: 5634 | X_test: 1409 | 5634 | 1409

# %%
X_train_scaled= scaler.fit_transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
print("Original training data:\n", X_train)
# Out:
# Original training data:
#        Gender  Age  Population  Number of Referrals  Tenure in Months  \
# 2663       0   38       43857                    9                69
# 2894       1   63       32268                    6                 7
# 2265       0   27       40836                    0                 1
# 4908       0   27       25859                    4                40
# 3621       1   40       33523                    9                71
# ...      ...  ...         ...                  ...               ...
# 3915       0   19       38519                    0                 1
# 1428       1   37        8525                    0                 1
# 6537       1   39       23570                    7                60
# 4367       0   59         128                    6                 2
# 2522       1   52       47431                    0                 4
#
#       Avg Monthly Long Distance Charges  Internet Service  \
# ...

# %%
print("\nScaled training data (mean=0, std=1):\n", X_train_scaled)
# Out:
# Scaled training data (mean=0, std=1):
#  [[-1.01286226 -0.51012814  1.03011315 ...  1.63485503 -0.80130322
#   -0.24539415]
#  [ 0.98730107  0.97585098  0.47958665 ... -0.61167503  1.24796703
#   -0.24539415]
#  [-1.01286226 -1.16395895  0.88660288 ... -0.61167503 -0.80130322
#   -0.24539415]
#  ...
#  [ 0.98730107 -0.45068897  0.06639488 ...  1.63485503 -0.80130322
#   -0.24539415]
#  [-1.01286226  0.73809432 -1.04719922 ... -0.61167503 -0.80130322
#    4.07507669]
#  [ 0.98730107  0.32202017  1.19989326 ... -0.61167503 -0.80130322
#   -0.24539415]]

# %%
print("\nScaled test data:\n", X_test_scaled)
# Out:
# Scaled test data:
#  [[-1.01286226 -1.40171561 -1.03271043 ... -0.61167503  1.24796703
#   -0.24539415]
#  [ 0.98730107  1.33248597 -0.87518641 ... -0.61167503 -0.80130322
#   -0.24539415]
#  [ 0.98730107  0.73809432  0.50870674 ...  1.63485503 -0.80130322
#   -0.24539415]
#  ...
#  [ 0.98730107 -1.40171561 -0.24642046 ... -0.61167503  1.24796703
#   -0.24539415]
#  [-1.01286226  1.62968179  0.16135583 ... -0.61167503 -0.80130322
#   -0.24539415]
#  [-1.01286226 -0.80732396  0.53944198 ... -0.61167503 -0.80130322
#   -0.24539415]]

# %%
# create model object
model = LogisticRegression(
    class_weight="balanced",
    penalty='l2',
    solver='sag',
    max_iter=1000
)

# train model with X scaled dataset
model.fit(X_train_scaled, y_train)

# test predict
y_pred = model.predict(X_test_scaled)

precision= precision_score(y_test, y_pred)
recall= recall_score(y_test, y_pred)

# Valudations
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"Accuracy: %{accuracy_score(y_test, y_pred) * 100:.0f}")
# Out:
# Precision: 0.56
# Recall: 0.83
# Accuracy: %77

# %%
import pickle

# model paths
scaler_path = _MODEL_FOLDER_PATH / "scaler.pkl"
model_path  =   _MODEL_FOLDER_PATH / "model.pkl"

# write models
with open(scaler_path, "wb") as f:
    pickle.dump(scaler, f)

with open(model_path, "wb") as f:
    pickle.dump(model, f)
